# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
samples_path = "/home/zhaochuyang/Workspace/openai_logs/cond/samples_16x64x64x3.npz"

samples = np.load(samples_path)["arr_0"]

# %%
b, c, h, w = samples.shape
print(b, c, h, w)
for i in range(b):
    plt.figure()
    plt.imshow(samples[i])
# Out:
# 16 64 64 3
